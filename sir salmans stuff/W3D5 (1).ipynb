# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([45, 50, 55, 60, 65, 70], index=range(0, 6))

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s
# Out:
# 0    45
# 1    50
# 2    55
# 3    60
# 4    65
# 5    70
# dtype: int64

# %%
random_arr = np.random.randint(10, size=(100))

# %%
random_arr
# Out:
# array([8, 7, 0, 8, 3, 6, 6, 8, 4, 4, 0, 7, 2, 0, 0, 5, 7, 8, 6, 1, 6, 0,
#        5, 5, 5, 8, 9, 7, 5, 3, 2, 5, 8, 7, 6, 3, 2, 9, 8, 8, 7, 4, 9, 0,
#        2, 7, 4, 9, 2, 6, 4, 8, 1, 8, 9, 8, 0, 2, 2, 6, 3, 4, 4, 4, 0, 5,
#        5, 2, 9, 4, 9, 7, 5, 5, 3, 1, 0, 5, 5, 2, 3, 3, 1, 1, 7, 6, 2, 0,
#        0, 5, 6, 8, 6, 7, 5, 8, 8, 4, 8, 9])

# %%
random_sr = pd.Series(random_arr, index=[f"index-{x}"  for x in range(0, 100)])

# %%
random_sr
# Out:
# index-0     8
# index-1     7
# index-2     0
# index-3     8
# index-4     3
#            ..
# index-95    8
# index-96    8
# index-97    4
# index-98    8
# index-99    9
# Length: 100, dtype: int64

# %%
random_arr ** 2
# Out:
# array([64, 49,  0, 64,  9, 36, 36, 64, 16, 16,  0, 49,  4,  0,  0, 25, 49,
#        64, 36,  1, 36,  0, 25, 25, 25, 64, 81, 49, 25,  9,  4, 25, 64, 49,
#        36,  9,  4, 81, 64, 64, 49, 16, 81,  0,  4, 49, 16, 81,  4, 36, 16,
#        64,  1, 64, 81, 64,  0,  4,  4, 36,  9, 16, 16, 16,  0, 25, 25,  4,
#        81, 16, 81, 49, 25, 25,  9,  1,  0, 25, 25,  4,  9,  9,  1,  1, 49,
#        36,  4,  0,  0, 25, 36, 64, 36, 49, 25, 64, 64, 16, 64, 81])

# %%
e = np.array([2] * 100)

# %%
age = pd.Series([29, 24, 19, 0], index=["Alice", 5, 6.7, "Ghulam"])

# %%
age[6.7]
# Out:
# 19

# %%
random_arr[0]
# Out:
# 8

# %%
type({"names":["Abc", "def", "ghi", "hkl"], "age": [1, 2, 3, 4]})
# Out:
# dict

# %%
 pd.DataFrame({"names":["Abc", "def", "ghi", "hkl"], "age": [1, 2, 3, 4]})
# Out:
#   names  age
# 0   Abc    1
# 1   def    2
# 2   ghi    3
# 3   hkl    4

# %%
pd.DataFrame([("Abc",1), ("def",2), ["ghi",3], ["hkl",4]], 
             columns=['name', 'age'],
             index=['a', 'b', 'c', 'd']
            )
# Out:
#   name  age
# a  Abc    1
# b  def    2
# c  ghi    3
# d  hkl    4

# %%
df = pd.read_csv("multi_index_practice.csv", 
                 sep=',', 
                 header=1,
                 dtype={"Name": str, "Position": str, "Salary": int},
                 # usecols=['Name', 'Position', 'Salary'],
                 converters = {"Name":lambda x: ":" + x, "Salary": lambda x: int(x)/1000000}
                 )

df
# Out:
# /tmp/ipykernel_4701/4226668799.py:1: ParserWarning: Both a converter and dtype were specified for column Name - only the converter will be used.
#   df = pd.read_csv("multi_index_practice.csv",
# /tmp/ipykernel_4701/4226668799.py:1: ParserWarning: Both a converter and dtype were specified for column Salary - only the converter will be used.
#   df = pd.read_csv("multi_index_practice.csv",
#        Name  Age Department   Position  Salary  Years of Experience
# 0    :Alice   25         HR    Manager   0.050                    3
# 1      :Bob   30         IT  Developer   0.060                    5
# 2  :Charlie   35         IT    Analyst   0.055                    4
# 3    :David   40    Finance    Manager   0.065                   10
# 4      :Eve   29         HR    Analyst   0.052                    2
# 5    :Frank   33    Finance  Developer   0.058                    6

# %%
df.dtypes
# Out:
# Name        object
# Position    object
# Salary       int64
# dtype: object

# %%
df.head(2)
# Out:
#      Name   Position  Salary
# 0  :Alice    Manager    0.05
# 1    :Bob  Developer    0.06

# %%
df.tail(1)
# Out:
#      Name   Position  Salary
# 5  :Frank  Developer   0.058

# %%
df.describe()
# Out:
#              Age    Salary  Years of Experience
# count   6.000000  6.000000             6.000000
# mean   32.000000  0.056667             5.000000
# std     5.215362  0.005502             2.828427
# min    25.000000  0.050000             2.000000
# 25%    29.250000  0.052750             3.250000
# 50%    31.500000  0.056500             4.500000
# 75%    34.500000  0.059500             5.750000
# max    40.000000  0.065000            10.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df['Department'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Position', 'Salary',
#        'Years of Experience'],
#       dtype='object')

# %%
df[['Name', 'Age']]
# Out:
#        Name  Age
# 0    :Alice   25
# 1      :Bob   30
# 2  :Charlie   35
# 3    :David   40
# 4      :Eve   29
# 5    :Frank   33

# %%
df.notnull().sum()
# Out:
# Name                   6
# Age                    6
# Department             6
# Position               6
# Salary                 6
# Years of Experience    6
# dtype: int64

# %%
df.map
# Out:
# <bound method DataFrame.map of        Name  Age Department   Position  Salary  Years of Experience
# 0    :Alice   25         HR    Manager   0.050                    3
# 1      :Bob   30         IT  Developer   0.060                    5
# 2  :Charlie   35         IT    Analyst   0.055                    4
# 3    :David   40    Finance    Manager   0.065                   10
# 4      :Eve   29         HR    Analyst   0.052                    2
# 5    :Frank   33    Finance  Developer   0.058                    6>

# %%
df.map(lambda x: x.replace(":", "") if type)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 df.map(lambda x: x.replace(":", ""))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10468, in DataFrame.map(self, func, na_action, **kwargs)
#   10465 def infer(x):
#   10466     return x._map_values(func, na_action=na_action)
# > 10468 return self.apply(infer).__finalize__(self, "map")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
pd
# Out:
# <module 'pandas' from '/home/noname/anaconda3/lib/python3.11/site-packages/pandas/__init__.py'>

# %%
df = pd.read_csv("multi_index_practice.csv", 
                 sep=',', 
                 header=1,
                 dtype={"Name": str, "Position": str, "Salary": int},
                 )

# %%
df[['Age', 'Name', 'Salary', 'Salary'],
# Out:
#    Age     Name  Salary  Salary
# 0   25    Alice   50000   50000
# 1   30      Bob   60000   60000
# 2   35  Charlie   55000   55000
# 3   40    David   65000   65000
# 4   29      Eve   52000   52000
# 5   33    Frank   58000   58000

# %%
df.iloc[0]
# Out:
# Name                     Alice
# Age                         25
# Department                  HR
# Position               Manager
# Salary                   50000
# Years of Experience          3
# Name: 0, dtype: object

# %%
df[['Age', 'Name' ]].iloc[::-1]
# Out:
#    Age     Name
# 5   33    Frank
# 4   29      Eve
# 3   40    David
# 2   35  Charlie
# 1   30      Bob
# 0   25    Alice

# %%
df = df.set_index('Name')

# %%
df
# Out:
#          Age Department   Position  Salary  Years of Experience
# Name
# Alice     25         HR    Manager   50000                    3
# Bob       30         IT  Developer   60000                    5
# Charlie   35         IT    Analyst   55000                    4
# David     40    Finance    Manager   65000                   10
# Eve       29         HR    Analyst   52000                    2
# Frank     33    Finance  Developer   58000                    6

# %%
df.loc['David':'Frank']
# Out:
#        Age Department   Position  Salary  Years of Experience
# Name
# David   40    Finance    Manager   65000                   10
# Eve     29         HR    Analyst   52000                    2
# Frank   33    Finance  Developer   58000                    6

# %%
df['Name'] = df.index

# %%
df = df.set_index("Department")

# %%
df
# Out:
#          Age Department   Position  Salary  Years of Experience
# Name
# Alice     25         HR    Manager   50000                    3
# Bob       30         IT  Developer   60000                    5
# Charlie   35         IT    Analyst   55000                    4
# David     40    Finance    Manager   65000                   10
# Eve       29         HR    Analyst   52000                    2
# Frank     33    Finance  Developer   58000                    6

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   Department     Name  Age   Position  Salary  Years of Experience
# 0         HR    Alice   25    Manager   50000                    3
# 1         IT      Bob   30  Developer   60000                    5
# 2         IT  Charlie   35    Analyst   55000                    4
# 3    Finance    David   40    Manager   65000                   10
# 4         HR      Eve   29    Analyst   52000                    2
# 5    Finance    Frank   33  Developer   58000                    6

# %%
np.array(df['Salary'] > 55000)
# Out:
# array([False,  True, False,  True, False,  True])

# %%
df[(df['Salary'] > 55000) & (df['Age'] > 30)]
# Out:
#   Department   Name  Age   Position  Salary  Years of Experience
# 3    Finance  David   40    Manager   65000                   10
# 5    Finance  Frank   33  Developer   58000                    6

# %%
(df['Salary'] > 55000).values and (df['Salary'] > 55000).values and (df['Age'] > 30).values
# Out:
# array([False,  True, False,  True, False,  True])

# %%
df['Age'] > 30
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# Name: Age, dtype: bool

# %%
df.iloc[0:4][['Age', 'Name']]
# Out:
#    Age     Name
# 0   25    Alice
# 1   30      Bob
# 2   35  Charlie
# 3   40    David

# %%
df[(df['Salary'] > 55000) & (df['Age'] > 30)]
# Out:
#   Department   Name  Age   Position  Salary  Years of Experience
# 3    Finance  David   40    Manager   65000                   10
# 5    Finance  Frank   33  Developer   58000                    6

# %%
df.set_index(['Department', 'Position'], inplace=True)

# %%
df
# Out:
#                          Name  Age  Salary  Years of Experience
# Department Position
# HR         Manager      Alice   25   50000                    3
# IT         Developer      Bob   30   60000                    5
#            Analyst    Charlie   35   55000                    4
# Finance    Manager      David   40   65000                   10
# HR         Analyst        Eve   29   52000                    2
# Finance    Developer    Frank   33   58000                    6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.loc['IT'].loc['Developer']
# Out:
# Name                     Bob
# Age                       30
# Salary                 60000
# Years of Experience        5
# Name: Developer, dtype: object

# %%
df.loc[[('IT', 'Developer'), ('IT', 'Analyst')]]
# Out:
#                          Name  Age  Salary  Years of Experience
# Department Position
# IT         Developer      Bob   30   60000                    5
#            Analyst    Charlie   35   55000                    4

# %%
df.loc['IT'].loc[['Developer', 'Analyst']]
# Out:
#               Name  Age  Salary  Years of Experience
# Position
# Developer      Bob   30   60000                    5
# Analyst    Charlie   35   55000                    4

# %%
df.reset_index(inplace=True)

# %%
df[df['Department'] == 'IT']
# Out:
#   Department   Position     Name  Age  Salary  Years of Experience
# 1         IT  Developer      Bob   30   60000                    5
# 2         IT    Analyst  Charlie   35   55000                    4

# %%
index = pd.MultiIndex.from_tuples([
	('USA', 2020),
	('USA', 2021),
	('Canada', 2020)
], names=['Country', 'Year'])
df = pd.DataFrame({'GDP': [21.4, 22.1, 1.6]}, index=index)

# %%
df
# Out:
#                GDP
# Country Year
# USA     2020  21.4
#         2021  22.1
# Canada  2020   1.6

# %%
df.reset_index()
# Out:
#   Country  Year   GDP
# 0     USA  2020  21.4
# 1     USA  2021  22.1
# 2  Canada  2020   1.6

# %%
df = pd.read_csv("multi_index_practice.csv", 
                 sep=',', 
                 header=[0,1],
                 dtype={"Name": str, "Position": str, "Salary": int},
                 # usecols=['Name', 'Position', 'Salary'],
                 converters = {"Name":lambda x: ":" + x, "Salary": lambda x: int(x)/1000000}
                 )

# %%
df.columns
# Out:
# MultiIndex([('Employee Info',                'Name'),
#             ('Employee Info',                 'Age'),
#             (     'Job Info',          'Department'),
#             (     'Job Info',            'Position'),
#             (     'Job Info',              'Salary'),
#             ('Employee Info', 'Years of Experience')],
#            )

# %%
df
# Out:
#   Employee Info       Job Info                         Employee Info
#            Name Age Department   Position Salary Years of Experience
# 0         Alice  25         HR    Manager  50000                   3
# 1           Bob  30         IT  Developer  60000                   5
# 2       Charlie  35         IT    Analyst  55000                   4
# 3         David  40    Finance    Manager  65000                  10
# 4           Eve  29         HR    Analyst  52000                   2
# 5         Frank  33    Finance  Developer  58000                   6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.columns
# Out:
# MultiIndex([('Employee Info',                'Name'),
#             ('Employee Info',                 'Age'),
#             (     'Job Info',          'Department'),
#             (     'Job Info',            'Position'),
#             (     'Job Info',              'Salary'),
#             ('Employee Info', 'Years of Experience')],
#            )

# %%
df.set_index([('Job Info', 'Department'),('Job Info','Position')], inplace=True)

# %%
df
# Out:
#                                             Employee Info     Job Info  \
#                                                      Name Age   Salary
# (Job Info, Department) (Job Info, Position)
# HR                     Manager                      Alice  25    50000
# IT                     Developer                      Bob  30    60000
#                        Analyst                    Charlie  35    55000
# Finance                Manager                      David  40    65000
# HR                     Analyst                        Eve  29    52000
# Finance                Developer                    Frank  33    58000
#
#                                                   Employee Info
#                                             Years of Experience
# (Job Info, Department) (Job Info, Position)
# HR                     Manager                                3
# IT                     Developer                              5
# ...

# %%
df.loc['Alice':'Eve']
# Out:
#                       Employee Info   Job Info                    \
#                                 Age Department   Position Salary
# (Employee Info, Name)
# Alice                            25         HR    Manager  50000
# Bob                              30         IT  Developer  60000
# Charlie                          35         IT    Analyst  55000
# David                            40    Finance    Manager  65000
# Eve                              29         HR    Analyst  52000
#
#                             Employee Info
#                       Years of Experience
# (Employee Info, Name)
# Alice                                   3
# Bob                                     5
# Charlie                                 4
# David                                  10
# Eve                                     2

# %%
df.reset_index(inplace=True)

# %%
df.shape
# Out:
# (6, 4)

# %%
df = pd.read_csv("multi_index_practice.csv", 
                 sep=',', 
                 header=[1],
                 dtype={"Name": str, "Position": str, "Salary": int},
                 # usecols=['Name', 'Position', 'Salary'],
                 converters = {"Name":lambda x: ":" + x, "Salary": lambda x: int(x)/1000000}
                 )
# Out:
# /tmp/ipykernel_3367/2682479670.py:1: ParserWarning: Both a converter and dtype were specified for column Name - only the converter will be used.
#   df = pd.read_csv("multi_index_practice.csv",
# /tmp/ipykernel_3367/2682479670.py:1: ParserWarning: Both a converter and dtype were specified for column Salary - only the converter will be used.
#   df = pd.read_csv("multi_index_practice.csv",

# %%
df.columns
# Out:
# MultiIndex([('Employee Info',                'Name',   'Alice'),
#             ('Employee Info',                 'Age',      '25'),
#             (     'Job Info',          'Department',      'HR'),
#             (     'Job Info',            'Position', 'Manager'),
#             (     'Job Info',              'Salary',   '50000'),
#             (     'Job Info', 'Years of Experience',       '3')],
#            )

# %%
# df.set_index(('Employee Info',                'Name',          'First Name')).loc['Alice']
# Out:
# Employee Info  Name                 Last Name                  NaN
#                Age                  Age                         25
# Job Info       Department           Department                  HR
#                Position             Position               Manager
#                Salary               Salary                   50000
# Employee Info  Years of Experience  Years of Experience          3
# Name: Alice, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 6 non-null      object
#  1   Age                  6 non-null      int64
#  2   Department           6 non-null      object
#  3   Position             6 non-null      object
#  4   Salary               6 non-null      float64
#  5   Years of Experience  6 non-null      int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 420.0+ bytes

# %%
int_values = [1, 2, 3, 4, 5]

text_values = ['alpha', 'beta', 'gamma', 'delta', 'epsilon']

float_values = [0.0, 0.25, 0.5, 0.75, 1.0]

df = pd.DataFrame({"int_col": int_values, "text_col": text_values,

                  "float_col": float_values})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   int_col    5 non-null      int64
#  1   text_col   5 non-null      object
#  2   float_col  5 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 252.0+ bytes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[264], line 1
# ----> 1 df.info().index
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
df['Department'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df['Department'].value_counts()
# Out:
# Department
# HR         2
# IT         2
# Finance    2
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# Name      Age  Department  Position   Salary  Years of Experience
# :Alice    25   HR          Manager    0.050   3                      1
# :Bob      30   IT          Developer  0.060   5                      1
# :Charlie  35   IT          Analyst    0.055   4                      1
# :David    40   Finance     Manager    0.065   10                     1
# :Eve      29   HR          Analyst    0.052   2                      1
# :Frank    33   Finance     Developer  0.058   6                      1
# Name: count, dtype: int64

# %%
df['Name'].apply(lambda x: x.replace(":", ""))
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# Name: Name, dtype: object

# %%
def removeColon(x):
    return x.replace(":", "")
df['Name'] = df['Name'].apply(removeColon)

# %%
df
# Out:
#       Name  Age Department   Position  Salary  Years of Experience
# 0    Alice   25         HR    Manager   0.050                    3
# 1      Bob   30         IT  Developer   0.060                    5
# 2  Charlie   35         IT    Analyst   0.055                    4
# 3    David   40    Finance    Manager   0.065                   10
# 4      Eve   29         HR    Analyst   0.052                    2
# 5    Frank   33    Finance  Developer   0.058                    6

# %%
df.apply(lambda x: print(x), raw=False)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# Name: Name, dtype: object
# 0    25
# 1    30
# 2    35
# 3    40
# 4    29
# 5    33
# Name: Age, dtype: int64
# 0         HR
# 1         IT
# 2         IT
# 3    Finance
# 4         HR
# 5    Finance
# Name: Department, dtype: object
# 0      Manager
# 1    Developer
# 2      Analyst
# 3      Manager
# 4      Analyst
# 5    Developer
# Name: Position, dtype: object
# 0    0.050
# 1    0.060
# 2    0.055
# 3    0.065
# 4    0.052
# 5    0.058
# Name: Salary, dtype: float64
# 0     3
# 1     5
# 2     4
# 3    10
# 4     2
# 5     6
# Name: Years of Experience, dtype: int64
# Name                   None
# Age                    None
# Department             None
# Position               None
# Salary                 None
# Years of Experience    None
# dtype: object

# %%
df.sort_values(['Department', "Age"], ascending=[True, False])
# Out:
#       Name  Age Department   Position  Salary  Years of Experience
# 3    David   40    Finance    Manager   0.065                   10
# 5    Frank   33    Finance  Developer   0.058                    6
# 4      Eve   29         HR    Analyst   0.052                    2
# 0    Alice   25         HR    Manager   0.050                    3
# 2  Charlie   35         IT    Analyst   0.055                    4
# 1      Bob   30         IT  Developer   0.060                    5

# %%
df.sort_index()
# Out:
#       Name  Age Department   Position  Salary  Years of Experience
# 0    Alice   25         HR    Manager   0.050                    3
# 1      Bob   30         IT  Developer   0.060                    5
# 2  Charlie   35         IT    Analyst   0.055                    4
# 3    David   40    Finance    Manager   0.065                   10
# 4      Eve   29         HR    Analyst   0.052                    2
# 5    Frank   33    Finance  Developer   0.058                    6

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.isnull().sum()
# Out:
# Name                   0
# Age                    1
# Department             0
# Position               1
# Salary                 0
# Years of Experience    4
# dtype: int64

# %%
df.dropna()
# Out:
#      Name   Age Department   Position  Salary  Years of Experience
# 0       :  25.0         HR    Manager   0.050                  3.0
# 5  :Frank  33.0    Finance  Developer   0.058                  6.0

# %%
df.fillna(10)
# Out:
#        Name   Age Department   Position  Salary  Years of Experience
# 0         :  25.0         HR    Manager   0.050                  3.0
# 1      :Bob  30.0         IT  Developer   0.060                 10.0
# 2  :Charlie  10.0         IT    Analyst   0.055                 10.0
# 3    :David  40.0    Finance    Manager   0.065                 10.0
# 4      :Eve  29.0         HR         10   0.052                 10.0
# 5    :Frank  33.0    Finance  Developer   0.058                  6.0
